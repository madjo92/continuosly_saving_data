# %%
from selenium import webdriver
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
driver = webdriver.Chrome(executable_path=r'C:\Users\vikto\Downloads\chromedriver_win32\chromedriver')
def get_imdb_top():
    url= 'https://www.imdb.com/chart/top/'
    driver.get(url)
    soup = bs(driver.page_source, 'lxml')
    table=soup.find('table', class_='chart')
    trs= soup.find_all('tr')
    for i in range(len(trs)):
        if i==0:
            continue
        print(trs[i].contents[3].text.strip().replace('\n','').replace('      ',''))    
    
    #for td in table.find_all('td', class_ = 'titleColumn'):
    #    print(td.text.strip().replace('\n','').replace('      ',''))

get_imdb_top()    
    
driver.close()
# Out:
# <ipython-input-30-9ba202d0cdbf>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r'C:\Users\vikto\Downloads\chromedriver_win32\chromedriver')
# 1.The Shawshank Redemption(1994)
# 2.The Godfather(1972)
# 3.The Godfather: Part II(1974)
# 4.The Dark Knight(2008)
# 5.12 Angry Men(1957)
# 6.Schindler's List(1993)
# 7.The Lord of the Rings: The Return of the King(2003)
# 8.Pulp Fiction(1994)
# 9.The Good, the Bad and the Ugly(1966)
# 10.The Lord of the Rings: The Fellowship of the Ring(2001)
# 11.Fight Club(1999)
# 12.Forrest Gump(1994)
# 13.Inception(2010)
# 14.The Lord of the Rings: The Two Towers(2002)
# 15.Star Wars: Episode V - The Empire Strikes Back(1980)
# 16.The Matrix(1999)
# 17.Goodfellas(1990)
# 18.One Flew Over the Cuckoo's Nest(1975)
# 19.Seven Samurai(1954)
# 20.Se7en(1995)
# 21.The Silence of the Lambs(1991)
# 22.City of God(2002)
# 23.Life Is Beautiful(1997)
# ...

# %%
print(trs[2].contents[3].text.strip().replace('\n','').replace('      ',''))
# Out:
# 2.The Godfather(1972)

# %%
driver = webdriver.Chrome(executable_path=r'C:\Users\vikto\Downloads\chromedriver_win32\chromedriver')
def get_imdb_top():
    url= 'https://www.imdb.com/chart/top/'
    driver.get(url)
    soup = bs(driver.page_source, 'lxml')
    table=soup.find('table', class_='chart')
    trs= soup.find_all('tr')
    for i in range(len(trs)):
        if i==0:
            continue
        full_title = trs[i].contents[3].text.strip().replace('\n','').replace('      ','')
        
        rank = full_title.split('.')[0]
        print('rank   : ', rank)
        
        title = full_title.split('.')[1].split('(')[0]
        print('title : ', title)
        
        year = full_title.split('(')[1][:-1]
        print('year   : ', year)

        a = td.find('a')
        print('link   : ', a['href'])

        print('\n')

    


get_imdb_top()    
    
driver.close()
# Out:
# <ipython-input-34-4bed4b36d00d>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r'C:\Users\vikto\Downloads\chromedriver_win32\chromedriver')
# rank   :  1
# title :  The Shawshank Redemption
# year   :  1994
# link   :  /title/tt10189514/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2f80ce0f-cde7-404b-a728-2edf16584db1&pf_rd_r=TPQ3B1FNQFA5M2BGEGD3&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_tt_250
#
#
# rank   :  2
# title :  The Godfather
# year   :  1972
# link   :  /title/tt10189514/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2f80ce0f-cde7-404b-a728-2edf16584db1&pf_rd_r=TPQ3B1FNQFA5M2BGEGD3&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_tt_250
#
#
# rank   :  3
# title :  The Godfather: Part II
# year   :  1974
# link   :  /title/tt10189514/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2f80ce0f-cde7-404b-a728-2edf16584db1&pf_rd_r=TPQ3B1FNQFA5M2BGEGD3&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_tt_250
#
#
# ...

# %%
dic = {}
x = trs[2].contents[3].text.strip().replace('\n','').replace('      ','').split('.')[1].split('(')[0]
m='title'
dic[m]=x
print(dic)
# Out:
# {'title': 'The Godfather'}

# %%
driver = webdriver.Chrome(executable_path=r'C:\Users\vikto\Downloads\chromedriver_win32\chromedriver')
def get_imdb_top():
    url= 'https://www.imdb.com/chart/top/'
    driver.get(url)
    soup = bs(driver.page_source, 'lxml')
    table=soup.find('table', class_='chart')
    trs= soup.find_all('tr')
    nameVal = {}
    ranks=[]
    titles=[]
    years=[]
    links=[]
    for i in range(len(trs)):
        
        if i==0:
            continue
        full_title = trs[i].contents[3].text.strip().replace('\n','').replace('      ','')
        
        rank = full_title.split('.')[0]
        ranks.append(rank)
        #r='rank'
        #nameVal[r]=rank
        #print('rank   : ', rank)
        
        title = full_title.split('.')[1].split('(')[0]
        titles.append(title)
        #t='title'
       # nameVal[t]=title
        #print('title : ', title)
        
        year = full_title.split('(')[1][:-1]
        years.append(year)
        #y='year'
        #nameVal[y]=year        
        #print('year   : ', year)

        a = td.find('a')
        links.append(a['href'])
        #li='link'
        #nameVal[li]=a['href']
        #print('link   : ', a['href'])

        #print('\n')
    #nameVal[r]=rank
    return ranks, titles, years, links

data = {"rank":[],
       "title":[],
       "year":[],
       "link":[]}
ranks, titles, years, links = get_imdb_top()
for i in range(len(ranks)):
    data["rank"].append(ranks[i])
    data["title"].append(titles[i])
    data["year"].append(years[i])
    data["link"].append(links[i])
    
df= pd.DataFrame(data)
df.to_csv("top250Imdb.csv")

   
driver.close()
# Out:
# <ipython-input-56-6b3ff6ef1745>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r'C:\Users\vikto\Downloads\chromedriver_win32\chromedriver')

# %%
df
# Out:
#     rank                     title  year  \
# 0      1  The Shawshank Redemption  1994
# 1      2             The Godfather  1972
# 2      3    The Godfather: Part II  1974
# 3      4           The Dark Knight  2008
# 4      5              12 Angry Men  1957
# ..   ...                       ...   ...
# 245  246        The Princess Bride  1987
# 246  247         Nights of Cabiria  1957
# 247  248              Paris, Texas  1984
# 248  249         Three Colors: Red  1994
# 249  250           Soorarai Pottru  2020
#
#                                                   link
# 0    /title/tt10189514/?pf_rd_m=A2FGELUUNOQJNL&pf_r...
# 1    /title/tt10189514/?pf_rd_m=A2FGELUUNOQJNL&pf_r...
# 2    /title/tt10189514/?pf_rd_m=A2FGELUUNOQJNL&pf_r...
# 3    /title/tt10189514/?pf_rd_m=A2FGELUUNOQJNL&pf_r...
# 4    /title/tt10189514/?pf_rd_m=A2FGELUUNOQJNL&pf_r...
# ..                                                 ...
# 245  /title/tt10189514/?pf_rd_m=A2FGELUUNOQJNL&pf_r...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   rank    250 non-null    object
#  1   title   250 non-null    object
#  2   year    250 non-null    object
#  3   link    250 non-null    object
# dtypes: object(4)
# memory usage: 7.9+ KB
